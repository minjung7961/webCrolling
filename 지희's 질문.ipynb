# %%
# !pip install pandas

# %%
# 외국인
import pandas as pd
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select("#frgn_deal_tab_0 > tbody > tr > td:nth-child(2) > a")
data = soup.select('#frgn_deal_tab_0 > tbody')

pd.DataFrame(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 외국인
import requests
from bs4 import BeautifulSoup
res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select("#frgn_deal_tab_0 > tbody > tr > td:nth-child(2) > a")

data = soup.select('#frgn_deal_tab_0 > tbody')

# %%
# !pip install lxml
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'C:\apps\webCrolling\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# 외국인
import lxml
import pandas as pd

df = pd.read_html('https://finance.naver.com/sise/',encoding='cp949')
df
# Out:
# [      업종명    전일대비 등락그래프
#  0     NaN     NaN   NaN
#  1     해운사  +7.74%  100%
#  2      은행  +5.01%   64%
#  3      철강  +4.72%   60%
#  4     NaN     NaN   NaN
#  5     NaN     NaN   NaN
#  6     NaN     NaN   NaN
#  7    생명보험  +3.71%   47%
#  8   석유와가스  +3.64%   47%
#  9    비철금속  +3.24%   41%
#  10    NaN     NaN   NaN
#  11    NaN     NaN   NaN,
#              테마명    전일대비         주도주
#  0           NaN     NaN         NaN
#  1          해저터널  +6.16%    상승  한국선재
#  2       철강 주요종목  +5.29%   상승  세아베스틸
#  3   LPG(액화석유가스)  +5.05%  상승  중앙에너비스
#  4           NaN     NaN         NaN
#  5           NaN     NaN         NaN
#  6           NaN     NaN         NaN
#  7            해운  +5.02%     상승  HMM
#  8            은행  +4.76%    상승  KB금융
#  9        철강 중소형  +4.71%    상승  동일제강
#  10          NaN     NaN         NaN
#  11          NaN     NaN         NaN,
#       0         1         2           3
#  0  NaN       NaN       NaN         NaN
#  1  NaN   SK이노베이션  280000.0   상승  6,500
# ...

# %%
len(df)
# Out:
# 6

# %%
df[2]
# Out:
#      0         1         2           3
# 0  NaN       NaN       NaN         NaN
# 1  NaN   SK이노베이션  280000.0   상승  6,500
# 2  NaN      LG화학  932000.0  상승  12,000
# 3  NaN      삼성전자   81900.0     하락  700
# 4  NaN       NaN       NaN         NaN
# 5  NaN       NaN       NaN         NaN
# 6  NaN       NaN       NaN         NaN
# 7  NaN      셀트리온  252000.0   하락  8,000
# 8  NaN     POSCO  394000.0  상승  17,500
# 9  NaN  셀트리온헬스케어  106900.0   하락  3,300
# 10 NaN       NaN       NaN         NaN
# 11 NaN       NaN       NaN         NaN

# %%
df[2]
# Out:
#      0         1         2           3
# 0  NaN       NaN       NaN         NaN
# 1  NaN   SK이노베이션  280000.0   상승  6,500
# 2  NaN      LG화학  932000.0  상승  12,000
# 3  NaN      삼성전자   81900.0     하락  700
# 4  NaN       NaN       NaN         NaN
# 5  NaN       NaN       NaN         NaN
# 6  NaN       NaN       NaN         NaN
# 7  NaN      셀트리온  252000.0   하락  8,000
# 8  NaN     POSCO  394000.0  상승  17,500
# 9  NaN  셀트리온헬스케어  106900.0   하락  3,300
# 10 NaN       NaN       NaN         NaN
# 11 NaN       NaN       NaN         NaN

# %%
df[1]
